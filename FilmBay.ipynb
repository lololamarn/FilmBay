-- %% [markdown]
-- # [camlens]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [camlens]    Script Date: 3/5/2024 16:05:03 ******/
CREATE DATABASE [camlens]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'camlens', FILENAME = N'A:\Program Files\SQL SERVER\MSSQL16.MSSQLSERVER\MSSQL\DATA\camlens.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'camlens_log', FILENAME = N'A:\Program Files\SQL SERVER\MSSQL16.MSSQLSERVER\MSSQL\DATA\camlens_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [camlens] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [camlens].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [camlens] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [camlens] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [camlens] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [camlens] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [camlens] SET ARITHABORT OFF 
GO
ALTER DATABASE [camlens] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [camlens] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [camlens] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [camlens] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [camlens] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [camlens] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [camlens] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [camlens] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [camlens] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [camlens] SET  DISABLE_BROKER 
GO
ALTER DATABASE [camlens] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [camlens] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [camlens] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [camlens] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [camlens] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [camlens] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [camlens] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [camlens] SET RECOVERY FULL 
GO
ALTER DATABASE [camlens] SET  MULTI_USER 
GO
ALTER DATABASE [camlens] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [camlens] SET DB_CHAINING OFF 
GO
ALTER DATABASE [camlens] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [camlens] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [camlens] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [camlens] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'camlens', N'ON'
GO
ALTER DATABASE [camlens] SET QUERY_STORE = ON
GO
ALTER DATABASE [camlens] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [zarc]

-- %%
USE [camlens]
GO

-- %%
/****** Object:  User [zarc]    Script Date: 3/5/2024 16:05:03 ******/
CREATE USER [zarc] FOR LOGIN [zarc] WITH DEFAULT_SCHEMA=[dbo]
GO

-- %% [markdown]
-- # [dbo].[Brand]

-- %%
/****** Object:  Table [dbo].[Brand]    Script Date: 3/5/2024 16:05:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Brand](
	[Brand_ID] [int] IDENTITY(1,1) NOT NULL,
	[Brand_Name] [varchar](100) NOT NULL,
	[Image] [nvarchar](max) NULL,
PRIMARY KEY CLUSTERED 
(
	[Brand_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cameras]

-- %%
/****** Object:  Table [dbo].[Cameras]    Script Date: 3/5/2024 16:05:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cameras](
	[Camera_ID] [int] IDENTITY(1,1) NOT NULL,
	[Camera_Name] [varchar](255) NOT NULL,
	[Brand] [int] NOT NULL,
	[Mount] [varchar](200) NULL,
	[Detalles] [varchar](max) NULL,
PRIMARY KEY CLUSTERED 
(
	[Camera_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Lenses]

-- %%
/****** Object:  Table [dbo].[Lenses]    Script Date: 3/5/2024 16:05:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Lenses](
	[Lens_ID] [int] IDENTITY(1,1) NOT NULL,
	[Lens_Name] [varchar](255) NOT NULL,
	[Brand] [int] NOT NULL,
	[Mount] [varchar](50) NULL,
	[Focal_length] [varchar](200) NULL,
	[Detalles] [varchar](max) NULL,
PRIMARY KEY CLUSTERED 
(
	[Lens_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Media]

-- %%
/****** Object:  Table [dbo].[Media]    Script Date: 3/5/2024 16:05:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Media](
	[Media_ID] [int] IDENTITY(1,1) NOT NULL,
	[Keyword] [nvarchar](max) NULL,
	[Brand] [int] NULL,
	[Camera] [int] NULL,
	[Lens] [int] NULL,
	[Img_URL] [nvarchar](max) NULL,
PRIMARY KEY CLUSTERED 
(
	[Media_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
/****** Object:  Table [dbo].[Users]    Script Date: 3/5/2024 16:05:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Users](
	[User_ID] [int] IDENTITY(1,1) NOT NULL,
	[Mail] [nvarchar](max) NULL,
	[Password] [nvarchar](max) NULL,
	[User_type] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[User_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__Cameras__Brand__4D94879B]

-- %%
ALTER TABLE [dbo].[Cameras]  WITH CHECK ADD FOREIGN KEY([Brand])
REFERENCES [dbo].[Brand] ([Brand_ID])
GO

-- %% [markdown]
-- # [FK__Lenses__Brand__4AB81AF0]

-- %%
ALTER TABLE [dbo].[Lenses]  WITH CHECK ADD FOREIGN KEY([Brand])
REFERENCES [dbo].[Brand] ([Brand_ID])
GO

-- %% [markdown]
-- # [FK__Media__Brand__2645B050]

-- %%
ALTER TABLE [dbo].[Media]  WITH CHECK ADD FOREIGN KEY([Brand])
REFERENCES [dbo].[Brand] ([Brand_ID])
GO

-- %% [markdown]
-- # [FK__Media__Camera__2739D489]

-- %%
ALTER TABLE [dbo].[Media]  WITH CHECK ADD FOREIGN KEY([Camera])
REFERENCES [dbo].[Cameras] ([Camera_ID])
GO

-- %% [markdown]
-- # [FK__Media__Lens__282DF8C2]

-- %%
ALTER TABLE [dbo].[Media]  WITH CHECK ADD FOREIGN KEY([Lens])
REFERENCES [dbo].[Lenses] ([Lens_ID])
GO

-- %% [markdown]
-- # [camlens]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [camlens] SET  READ_WRITE 
GO
